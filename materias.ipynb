# %%
import pandas as pd

materias = pd.read_csv("electivas.csv")
materias
# Out:
#                                      Actividad     Tipo  Año  Período  Nota  \
# 0                   MATEMATICA DISCRETA (6107)  Materia  NaN      NaN   NaN
# 1             ANALISIS MATEMATICO III A (6110)  Materia  NaN      NaN   NaN
# 2   ECUACIONES DIFERENCIALES ORDINARIAS (6118)  Materia  NaN      NaN   NaN
# 3                    ANALISIS FUNCIONAL (6119)  Materia  NaN      NaN   NaN
# 4                     MECANICA RACIONAL (6211)  Materia  NaN      NaN   NaN
# ..                                         ...      ...  ...      ...   ...
# 73    ACTIVIDADES ACADEMICAS AFINES 16 (AAF16)  Materia  NaN      NaN   NaN
# 74    ACTIVIDADES ACADEMICAS AFINES 24 (AAF24)  Materia  NaN      NaN   NaN
# 75    ACTIVIDADES ACADEMICAS AFINES 26 (AAF26)  Materia  NaN      NaN   NaN
# 76      ACTIVIDADES ACADEMICAS AFINES 9 (AAF9)  Materia  NaN      NaN   NaN
# 77    ACTIVIDADES ACADEMICAS AFINES 39 (AAF39)  Materia  NaN      NaN   NaN
#
#     Origen  Créditos  Puntaje
# ...

# %%
materias.drop(columns=["Año", "Período", "Nota", "Origen", "Puntaje"], inplace=True)

# %%
materias
# Out:
#                                      Actividad     Tipo  Créditos
# 0                   MATEMATICA DISCRETA (6107)  Materia       6.0
# 1             ANALISIS MATEMATICO III A (6110)  Materia       6.0
# 2   ECUACIONES DIFERENCIALES ORDINARIAS (6118)  Materia       6.0
# 3                    ANALISIS FUNCIONAL (6119)  Materia       6.0
# 4                     MECANICA RACIONAL (6211)  Materia       4.0
# ..                                         ...      ...       ...
# 73    ACTIVIDADES ACADEMICAS AFINES 16 (AAF16)  Materia      16.0
# 74    ACTIVIDADES ACADEMICAS AFINES 24 (AAF24)  Materia      24.0
# 75    ACTIVIDADES ACADEMICAS AFINES 26 (AAF26)  Materia      26.0
# 76      ACTIVIDADES ACADEMICAS AFINES 9 (AAF9)  Materia       9.0
# 77    ACTIVIDADES ACADEMICAS AFINES 39 (AAF39)  Materia      39.0
#
# [78 rows x 3 columns]

# %%
materias.to_csv("electivas_procesado.csv")
